# %% [markdown]
# <a href="https://colab.research.google.com/github/Arthur280708/ctfe-1ema/blob/main/Aula_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
m1, m2, m3, m4 = input('Insira os valores da distribuiçao; ').split()
m1 = int(m1)
m2 = int(m2)
m3 = int(m3)
m4 = int(m4)
#Media
media1 = (m1 + m2 + m3 + m4) /4
#Desvios
d10 = m1 - media1
d20 = m2 - media1
d30 = m3 - media1
d40 = m4 - medoa1
#variancia ----> Populacional(quando temos todos os dados observados)
variancia1 = (d10**2 + d20**2 + d30**2 + d40**2) / 4
#desvio padrao
desvio1 = variancia1**0.5
print(f'A variancia da destribuiçao {m1}, {m2}, {m3} e {m4} sera de:\n{variancia1 ;.2f}')
print(f'O desvio padrao dessa distribuiçao sera ;\n{desvio1;.3f}')
# Out:
#   File "/tmp/ipykernel_20679/2905839174.py", line 17
#     print(f'A variancia da destribuiçao {m1}, {m2}, {m3} e {m4} sera de:\n{variancia1 ;.2f}')
#                                                                                       ^
# SyntaxError: f-string: expecting '=', or '!', or ':', or '}'

# %%
m1, m2, m3, m4 = input('Insira os valores da distribuiçao; ').split()
m1 = int(m1)
m2 = int(m2)
m3 = int(m3)
m4 = int(m4)
#Media
media1 = (m1 + m2 + m3 + m4) /4
#Desvios
d10 = m1 - media1
d20 = m2 - media1
d30 = m3 - media1
d40 = m4 - media1
#variancia ----> Populacional(quando temos todos os dados observados)
variancia1 = (d10**2 + d20**2 + d30**2 + d40**2) / 4
#desvio padrao
desvio1 = variancia1**0.5
print(f'A variancia da destribuiçao {m1}, {m2}, {m3} e {m4} sera de;\n{variancia1:.2f}')
print(f'O desvio padrao dessa distribuiçao sera :\n{desvio1:.3f}')
# Out:
# Insira os valores da distribuiçao; 20 1 7 12
# A variancia da destribuiçao 20, 1, 7 e 12 sera de;
# 48.50
# O desvio padrao dessa distribuiçao sera :
# 6.964
